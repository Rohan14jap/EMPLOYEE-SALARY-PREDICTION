# %%
import pandas as pd
data = pd.read_csv("adult 3.csv")  # assuming you uploaded it with this name

# %%
data.isna()
# Out:
#          age  workclass  fnlwgt  education  educational-num  marital-status  \
# 0      False      False   False      False            False           False
# 1      False      False   False      False            False           False
# 2      False      False   False      False            False           False
# 3      False      False   False      False            False           False
# 4      False      False   False      False            False           False
# ...      ...        ...     ...        ...              ...             ...
# 48837  False      False   False      False            False           False
# 48838  False      False   False      False            False           False
# 48839  False      False   False      False            False           False
# 48840  False      False   False      False            False           False
# 48841  False      False   False      False            False           False
#
# ...

# %%
data.isna().sum()
# Out:
# age                0
# workclass          0
# fnlwgt             0
# education          0
# educational-num    0
# marital-status     0
# occupation         0
# relationship       0
# race               0
# gender             0
# capital-gain       0
# capital-loss       0
# hours-per-week     0
# native-country     0
# income             0
# dtype: int64

# %%
data.tail(7)
# Out:
#        age     workclass  fnlwgt     education  educational-num  \
# 48835   53       Private  321865       Masters               14
# 48836   22       Private  310152  Some-college               10
# 48837   27       Private  257302    Assoc-acdm               12
# 48838   40       Private  154374       HS-grad                9
# 48839   58       Private  151910       HS-grad                9
# 48840   22       Private  201490       HS-grad                9
# 48841   52  Self-emp-inc  287927       HS-grad                9
#
#            marital-status         occupation   relationship   race  gender  \
# 48835  Married-civ-spouse    Exec-managerial        Husband  White    Male
# 48836       Never-married    Protective-serv  Not-in-family  White    Male
# 48837  Married-civ-spouse       Tech-support           Wife  White  Female
# 48838  Married-civ-spouse  Machine-op-inspct        Husband  White    Male
# 48839             Widowed       Adm-clerical      Unmarried  White  Female
# ...

# %%
print(data.occupation.value_counts())
# Out:
# occupation
# Prof-specialty       6172
# Craft-repair         6112
# Exec-managerial      6086
# Adm-clerical         5611
# Sales                5504
# Other-service        4923
# Machine-op-inspct    3022
# ?                    2809
# Transport-moving     2355
# Handlers-cleaners    2072
# Farming-fishing      1490
# Tech-support         1446
# Protective-serv       983
# Priv-house-serv       242
# Armed-Forces           15
# Name: count, dtype: int64

# %%
print(data.gender.value_counts())
# Out:
# gender
# Male      32650
# Female    16192
# Name: count, dtype: int64

# %%
print(data['marital-status'].value_counts())
# Out:
# marital-status
# Married-civ-spouse       22379
# Never-married            16117
# Divorced                  6633
# Separated                 1530
# Widowed                   1518
# Married-spouse-absent      628
# Married-AF-spouse           37
# Name: count, dtype: int64

# %%
data.occupation.replace({'?': 'Others'}, inplace=True)
# Out:
# /tmp/ipython-input-9-2301306202.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data.occupation.replace({'?': 'Others'}, inplace=True)

# %%
print(data.occupation.value_counts())
# Out:
# occupation
# Prof-specialty       6172
# Craft-repair         6112
# Exec-managerial      6086
# Adm-clerical         5611
# Sales                5504
# Other-service        4923
# Machine-op-inspct    3022
# Others               2809
# Transport-moving     2355
# Handlers-cleaners    2072
# Farming-fishing      1490
# Tech-support         1446
# Protective-serv       983
# Priv-house-serv       242
# Armed-Forces           15
# Name: count, dtype: int64

# %%
data.workclass.replace({'?': 'NotListed'}, inplace=True)
# Out:
# /tmp/ipython-input-11-2870584934.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data.workclass.replace({'?': 'NotListed'}, inplace=True)

# %%
print(data.workclass.value_counts())
# Out:
# workclass
# Private             33906
# Self-emp-not-inc     3862
# Local-gov            3136
# NotListed            2799
# State-gov            1981
# Self-emp-inc         1695
# Federal-gov          1432
# Without-pay            21
# Never-worked           10
# Name: count, dtype: int64

# %%
data=data[data['workclass']!='Without-pay']
data=data[data['workclass']!='Never-worked']

# %%
print(data.workclass.value_counts())
# Out:
# workclass
# Private             33906
# Self-emp-not-inc     3862
# Local-gov            3136
# NotListed            2799
# State-gov            1981
# Self-emp-inc         1695
# Federal-gov          1432
# Name: count, dtype: int64

# %%
data.shape
# Out:
# (48811, 15)

# %%
print(data.education.value_counts())
# Out:
# education
# HS-grad         15768
# Some-college    10873
# Bachelors        8025
# Masters          2657
# Assoc-voc        2061
# 11th             1809
# Assoc-acdm       1599
# 10th             1387
# 7th-8th           952
# Prof-school       834
# 9th               756
# 12th              657
# Doctorate         594
# 5th-6th           509
# 1st-4th           247
# Preschool          83
# Name: count, dtype: int64

# %%
data.drop(columns=['education'],inplace=True)

# %%
data
# Out:
#        age     workclass  fnlwgt  educational-num      marital-status  \
# 0       25       Private  226802                7       Never-married
# 1       38       Private   89814                9  Married-civ-spouse
# 2       28     Local-gov  336951               12  Married-civ-spouse
# 3       44       Private  160323               10  Married-civ-spouse
# 4       18     NotListed  103497               10       Never-married
# ...    ...           ...     ...              ...                 ...
# 48837   27       Private  257302               12  Married-civ-spouse
# 48838   40       Private  154374                9  Married-civ-spouse
# 48839   58       Private  151910                9             Widowed
# 48840   22       Private  201490                9       Never-married
# 48841   52  Self-emp-inc  287927                9  Married-civ-spouse
#
#               occupation relationship   race  gender  capital-gain  \
# ...

# %%
import matplotlib.pyplot as plt
plt.boxplot(data['age'])
plt.show()

# %%
data = data[(data['age'] <= 75) & (data['age'] >= 17)]

# %%
import matplotlib.pyplot as plt
plt.boxplot(data['age'])
plt.show()

# %%
x=data.drop(columns=['income'])
y=data['income']
x



from sklearn.preprocessing import LabelEncoder

encoder = LabelEncoder()
data['workclass'] = encoder.fit_transform(data['workclass'])

data['marital-status'] = encoder.fit_transform(data['marital-status'])
data['occupation'] = encoder.fit_transform(data['occupation'])
data['relationship'] = encoder.fit_transform(data['relationship'])
data['race'] = encoder.fit_transform(data['race'])
data['gender'] = encoder.fit_transform(data['gender'])
data['native-country'] = encoder.fit_transform(data['native-country'])
# Out:
# /tmp/ipython-input-22-131988450.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['workclass'] = encoder.fit_transform(data['workclass'])
# /tmp/ipython-input-22-131988450.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['marital-status'] = encoder.fit_transform(data['marital-status'])
# /tmp/ipython-input-22-131988450.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# ...

# %%
from sklearn.preprocessing import LabelEncoder

# Create a copy of the data to avoid modifying the original
data_copy = data.copy()

# Columns to encode (excluding 'income')
categorical_cols = ['workclass', 'marital-status', 'occupation', 'relationship',
                    'race', 'gender', 'native-country']

encoder = LabelEncoder()

# Encode categorical features (but NOT 'income')
for col in categorical_cols:
    data_copy[col] = encoder.fit_transform(data_copy[col])

# Features without modifying 'income' in the table
X = data_copy.drop(columns=['income'])

# Encode 'income' separately for target variable
y = encoder.fit_transform(data_copy['income'])  # this doesn't change the main table

# %%
data
# Out:
#        age  workclass  fnlwgt  educational-num  marital-status  occupation  \
# 0       25          3  226802                7               4           6
# 1       38          3   89814                9               2           4
# 2       28          1  336951               12               2          11
# 3       44          3  160323               10               2           6
# 4       18          2  103497               10               4           8
# ...    ...        ...     ...              ...             ...         ...
# 48837   27          3  257302               12               2          13
# 48838   40          3  154374                9               2           6
# 48839   58          3  151910                9               6           0
# 48840   22          3  201490                9               4           0
# 48841   52          4  287927                9               2           3
#
# ...

# %%
from sklearn.preprocessing import LabelEncoder

# Make a copy so original data stays safe
data_copy = data.copy()

# Initialize encoder
encoder = LabelEncoder()

# Columns to encode (EXCLUDE 'income')
columns_to_encode = ['workclass', 'marital-status', 'occupation', 'relationship',
                     'race', 'gender', 'native-country']

# Apply label encoding to only those columns
for col in columns_to_encode:
    data_copy[col] = encoder.fit_transform(data_copy[col])

# Now create features and target
X = data_copy.drop(columns=['income'])  # Encoded features
y = data_copy['income']  # Target column as string labels ('>50K' / '<=50K')

# %%
data
# Out:
#        age  workclass  fnlwgt  educational-num  marital-status  occupation  \
# 0       25          3  226802                7               4           6
# 1       38          3   89814                9               2           4
# 2       28          1  336951               12               2          11
# 3       44          3  160323               10               2           6
# 4       18          2  103497               10               4           8
# ...    ...        ...     ...              ...             ...         ...
# 48837   27          3  257302               12               2          13
# 48838   40          3  154374                9               2           6
# 48839   58          3  151910                9               6           0
# 48840   22          3  201490                9               4           0
# 48841   52          4  287927                9               2           3
#
# ...

# %%
import pandas as pd

# Load the dataset from file
data = pd.read_csv('adult 3.csv')  # <-- use the correct file name here

# Now you can apply label encoding
from sklearn.preprocessing import LabelEncoder
encoder = LabelEncoder()

data['workclass']        = encoder.fit_transform(data['workclass'])
data['marital-status']   = encoder.fit_transform(data['marital-status'])
data['occupation']       = encoder.fit_transform(data['occupation'])
data['relationship']     = encoder.fit_transform(data['relationship'])
data['race']             = encoder.fit_transform(data['race'])
data['gender']           = encoder.fit_transform(data['gender'])
data['native-country']   = encoder.fit_transform(data['native-country'])

# View result
data.head()
# Out:
#    age  workclass  fnlwgt     education  educational-num  marital-status  \
# 0   25          4  226802          11th                7               4
# 1   38          4   89814       HS-grad                9               2
# 2   28          2  336951    Assoc-acdm               12               2
# 3   44          4  160323  Some-college               10               2
# 4   18          0  103497  Some-college               10               4
#
#    occupation  relationship  race  gender  capital-gain  capital-loss  \
# 0           7             3     2       1             0             0
# 1           5             0     4       1             0             0
# 2          11             0     4       1             0             0
# 3           7             0     2       1          7688             0
# 4           0             3     4       0             0             0
#
#    hours-per-week  native-country income
# 0              40              39  <=50K
# ...

# %%
data
# Out:
#        age  workclass  fnlwgt     education  educational-num  marital-status  \
# 0       25          4  226802          11th                7               4
# 1       38          4   89814       HS-grad                9               2
# 2       28          2  336951    Assoc-acdm               12               2
# 3       44          4  160323  Some-college               10               2
# 4       18          0  103497  Some-college               10               4
# ...    ...        ...     ...           ...              ...             ...
# 48837   27          4  257302    Assoc-acdm               12               2
# 48838   40          4  154374       HS-grad                9               2
# 48839   58          4  151910       HS-grad                9               6
# 48840   22          4  201490       HS-grad                9               4
# 48841   52          5  287927       HS-grad                9               2
#
# ...

# %%
print(data['education'].unique())
# Out:
# ['11th' 'HS-grad' 'Assoc-acdm' 'Some-college' '10th' 'Prof-school'
#  '7th-8th' 'Bachelors' 'Masters' 'Doctorate' '5th-6th' 'Assoc-voc' '9th'
#  '12th' '1st-4th' 'Preschool']

# %%
# Check values first (optional)
print(data['education'].unique())

# Keep only people with education level 12th or above
keep_educations = [
     'HS-grad', 'Some-college', 'Assoc-acdm', 'Assoc-voc',
    'Bachelors', 'Masters', 'Doctorate', 'Prof-school'
]

data = data[data['education'].isin(keep_educations)]

# Optional: Reset index after dropping rows
data = data.reset_index(drop=True)

# Confirm result
print(data['education'].unique())
# Out:
# ['11th' 'HS-grad' 'Assoc-acdm' 'Some-college' '10th' 'Prof-school'
#  '7th-8th' 'Bachelors' 'Masters' 'Doctorate' '5th-6th' 'Assoc-voc' '9th'
#  '12th' '1st-4th' 'Preschool']
# ['HS-grad' 'Assoc-acdm' 'Some-college' 'Prof-school' 'Bachelors' 'Masters'
#  'Doctorate' 'Assoc-voc']

# %%
data
# Out:
#        age  workclass  fnlwgt     education  educational-num  marital-status  \
# 0       38          4   89814       HS-grad                9               2
# 1       28          2  336951    Assoc-acdm               12               2
# 2       44          4  160323  Some-college               10               2
# 3       18          0  103497  Some-college               10               4
# 4       29          0  227026       HS-grad                9               4
# ...    ...        ...     ...           ...              ...             ...
# 42429   27          4  257302    Assoc-acdm               12               2
# 42430   40          4  154374       HS-grad                9               2
# 42431   58          4  151910       HS-grad                9               6
# 42432   22          4  201490       HS-grad                9               4
# 42433   52          5  287927       HS-grad                9               2
#
# ...

# %%
data = data[data['age'] >= 18]

# Optional: Reset index
data = data.reset_index(drop=True)

# View the cleaned data
print(data.head())
# Out:
#    age  workclass  fnlwgt     education  educational-num  marital-status  \
# 0   38          4   89814       HS-grad                9               2
# 1   28          2  336951    Assoc-acdm               12               2
# 2   44          4  160323  Some-college               10               2
# 3   18          0  103497  Some-college               10               4
# 4   29          0  227026       HS-grad                9               4
#
#    occupation  relationship  race  gender  capital-gain  capital-loss  \
# 0           5             0     4       1             0             0
# 1          11             0     4       1             0             0
# 2           7             0     2       1          7688             0
# 3           0             3     4       0             0             0
# 4           0             4     2       1             0             0
#
#    hours-per-week  native-country income
# 0              50              39  <=50K
# ...

# %%
data
# Out:
#        age  workclass  fnlwgt     education  educational-num  marital-status  \
# 0       38          4   89814       HS-grad                9               2
# 1       28          2  336951    Assoc-acdm               12               2
# 2       44          4  160323  Some-college               10               2
# 3       18          0  103497  Some-college               10               4
# 4       29          0  227026       HS-grad                9               4
# ...    ...        ...     ...           ...              ...             ...
# 42410   27          4  257302    Assoc-acdm               12               2
# 42411   40          4  154374       HS-grad                9               2
# 42412   58          4  151910       HS-grad                9               6
# 42413   22          4  201490       HS-grad                9               4
# 42414   52          5  287927       HS-grad                9               2
#
# ...

# %%
y
# Out:
# 0        <=50K
# 1        <=50K
# 2         >50K
# 3         >50K
# 4        <=50K
#          ...
# 48837    <=50K
# 48838     >50K
# 48839    <=50K
# 48840    <=50K
# 48841     >50K
# Name: income, Length: 48438, dtype: object

# %%
from sklearn.preprocessing import LabelEncoder

# Encode each column with object (string) type
for col in x.select_dtypes(include='object').columns:
    encoder = LabelEncoder()
    x[col] = encoder.fit_transform(x[col])

# %%
from sklearn.preprocessing import MinMaxScaler

scaler = MinMaxScaler()
x_scaled = scaler.fit_transform(x)

# %%
import pandas as pd
x = pd.DataFrame(x_scaled, columns=x.columns)

# %%
x
# Out:
#             age  workclass    fnlwgt  educational-num  marital-status  \
# 0      0.137931   0.500000  0.145129         0.400000        0.666667
# 1      0.362069   0.500000  0.052451         0.533333        0.333333
# 2      0.189655   0.166667  0.219649         0.733333        0.333333
# 3      0.465517   0.500000  0.100153         0.600000        0.333333
# 4      0.017241   0.333333  0.061708         0.600000        0.666667
# ...         ...        ...       ...              ...             ...
# 48433  0.172414   0.500000  0.165763         0.733333        0.333333
# 48434  0.396552   0.500000  0.096129         0.533333        0.333333
# 48435  0.706897   0.500000  0.094462         0.533333        1.000000
# 48436  0.086207   0.500000  0.128004         0.533333        0.666667
# 48437  0.603448   0.666667  0.186482         0.533333        0.333333
#
#        occupation  relationship  race  gender  capital-gain  capital-loss  \
# ...

# %%
from sklearn.model_selection import train_test_split
xtrain,xtest,ytrain,ytest=train_test_split(x,y,test_size=0.2,random_state=23,stratify=y)

# %%
xtrain
# Out:
#             age  workclass    fnlwgt  educational-num  marital-status  \
# 35839  0.344828   0.833333  0.111623         0.600000        0.666667
# 39790  0.827586   0.666667  0.098178         0.533333        0.333333
# 25772  0.120690   0.500000  0.235126         0.800000        0.333333
# 6084   0.482759   0.833333  0.039556         0.933333        0.333333
# 16668  0.379310   0.166667  0.132309         0.466667        0.333333
# ...         ...        ...       ...              ...             ...
# 40899  0.448276   0.666667  0.087072         0.800000        0.333333
# 29596  0.258621   0.500000  0.048013         0.600000        0.333333
# 11005  0.275862   0.500000  0.104361         0.200000        0.333333
# 25474  0.775862   0.500000  0.115992         0.600000        0.333333
# 35772  0.344828   0.500000  0.182304         0.600000        0.000000
#
#        occupation  relationship  race  gender  capital-gain  capital-loss  \
# ...

# %%
from sklearn.preprocessing import LabelEncoder, MinMaxScaler
from sklearn.model_selection import train_test_split

# Step 1: Encode categorical columns (if any)
for col in x.select_dtypes(include='object').columns:
    x[col] = LabelEncoder().fit_transform(x[col])

# Step 2: Scale numeric data
scaler = MinMaxScaler()
x_scaled = scaler.fit_transform(x)  # This returns a NumPy array

# Step 3: Split the dataset into training and testing sets
xtrain, xtest, ytrain, ytest = train_test_split(
    x_scaled, y, test_size=0.2, random_state=23, stratify=y
)

# Step 4: Show the training data
xtrain
# Out:
# array([[0.34482759, 0.83333333, 0.11162325, ..., 0.        , 0.39795918,
#         0.95121951],
#        [0.82758621, 0.66666667, 0.09817775, ..., 0.        , 0.5       ,
#         0.95121951],
#        [0.12068966, 0.5       , 0.23512582, ..., 0.        , 0.43877551,
#         0.95121951],
#        ...,
#        [0.27586207, 0.5       , 0.1043613 , ..., 0.        , 0.39795918,
#         0.95121951],
#        [0.77586207, 0.5       , 0.11599233, ..., 0.        , 0.39795918,
#         0.95121951],
#        [0.34482759, 0.5       , 0.18230381, ..., 0.        , 0.29591837,
#         0.95121951]])

# %%
# Step 1: Import the classifier
from sklearn.neighbors import KNeighborsClassifier

# Step 2: Create the model
knn = KNeighborsClassifier()

# Step 3: Train the model
knn.fit(xtrain, ytrain)  # xtrain: features, ytrain: income as string labels

# Step 4: Predict
predict = knn.predict(xtest)

# Step 5: View the output
predict
                                      # Optional: show predictions
# Out:
# array(['<=50K', '<=50K', '<=50K', ..., '<=50K', '<=50K', '<=50K'],
#       dtype=object)

# %%
from sklearn.metrics import accuracy_score
accuracy_score(ytest,predict)
# Out:
# 0.8268992568125516

# %%
# Step 1: Import the classifier
from sklearn.linear_model import LogisticRegression

# Step 2: Create the model
lr = LogisticRegression(max_iter=1000)  # Increase max_iter to avoid convergence warnings

# Step 3: Train the model
lr.fit(xtrain, ytrain)  # xtrain: features, ytrain: target (like 'income')

# Step 4: Predict
predict = lr.predict(xtest)

# Step 5: View the output
print(predict)
# Out:
# ['<=50K' '<=50K' '<=50K' ... '<=50K' '<=50K' '<=50K']

# %%
from sklearn.metrics import accuracy_score
accuracy_score(ytest,predict)
# Out:
# 0.8236994219653179

# %%
# Step 1: Import the classifier
from sklearn.linear_model import LogisticRegression

# Step 2: Create the model
lr = LogisticRegression(max_iter=1000)  # Increase max_iter to avoid convergence warnings

# Step 3: Train the model
lr.fit(xtrain, ytrain)  # xtrain: features, ytrain: target (like 'income')

# Step 4: Predict
predict = lr.predict(xtest)

# Step 5: View the output
print(predict)
# Out:
# ['<=50K' '<=50K' '<=50K' ... '<=50K' '<=50K' '<=50K']

# %%
from sklearn.neural_network import MLPClassifier

mlp = MLPClassifier(solver='adam',hidden_layer_sizes=(5,2),random_state=2,max_iter=2000)
mlp.fit(xtrain, ytrain)

predict2 = mlp.predict(xtest)

# %%
from sklearn.metrics import accuracy_score
accuracy_score(ytest,predict2)
# Out:
# 0.8442402972749794

# %%
# 📌 Step 1: Import Required Libraries
from sklearn.pipeline import Pipeline
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, classification_report

from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC

from sklearn.preprocessing import StandardScaler

# 📌 Step 2: Assume you have x and y already defined
# x = features (after encoding + scaling)
# y = target variable (like income)

# 📌 Step 3: Split the Data
X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)

# 📌 Step 4: Define Models
models = {
    "LogisticRegression": LogisticRegression(),
    "RandomForest": RandomForestClassifier(),
    "KNN": KNeighborsClassifier(),
    "SVM": SVC(),
    "GradientBoosting": GradientBoostingClassifier()
}

# 📌 Step 5: Train & Evaluate with Pipeline
results = {}

for name, model in models.items():
    pipe = Pipeline([
        ('scaler', StandardScaler()),   # Scale features
        ('model', model)                # Classification model
    ])

    # Train the pipeline
    pipe.fit(X_train, y_train)

    # Make predictions
    predictions = pipe.predict(X_test)

    # Evaluate
    acc = accuracy_score(y_test, predictions)
    report = classification_report(y_test, predictions)

    results[name] = {
        "accuracy": acc,
        "report": report
    }

# 📌 Step 6: Print Results
for name, metrics in results.items():
    print(f"\n===== {name} =====")
    print("Accuracy:", metrics["accuracy"])
    print("Classification Report:\n", metrics["report"])
# Out:
# ===== LogisticRegression =====
# Accuracy: 0.8273121387283237
# Classification Report:
#                precision    recall  f1-score   support
#
#        <=50K       0.84      0.95      0.89      7323
#         >50K       0.74      0.46      0.56      2365
#
#     accuracy                           0.83      9688
#    macro avg       0.79      0.70      0.73      9688
# weighted avg       0.82      0.83      0.81      9688
#
#
# ===== RandomForest =====
# Accuracy: 0.8588976052848886
# Classification Report:
#                precision    recall  f1-score   support
#
#        <=50K       0.89      0.93      0.91      7323
#         >50K       0.75      0.63      0.68      2365
#
#     accuracy                           0.86      9688
#    macro avg       0.82      0.78      0.80      9688
# weighted avg       0.85      0.86      0.85      9688
#
#
# ===== KNN =====
# Accuracy: 0.828447563996697
# Classification Report:
#                precision    recall  f1-score   support
#
# ...

# %%
# !pip install catboost
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 99.2/99.2 MB 7.0 MB/s eta 0:00:00
# ...

# %%
import pandas as pd
import numpy as np
from catboost import CatBoostClassifier, Pool
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, classification_report

# %%
data = pd.read_csv("adult 3.csv")

# Replace ? with proper labels
data['occupation'].replace('?', 'Others', inplace=True)
data['workclass'].replace('?', 'NotListed', inplace=True)

# Remove rows that are not actual workers
data = data[~data['workclass'].isin(['Without-pay', 'Never-worked'])]

# Keep people aged 18–75
data = data[(data['age'] >= 18) & (data['age'] <= 75)]

# Keep education level 12th or above
keep_educations = ['HS-grad', 'Some-college', 'Assoc-acdm', 'Assoc-voc',
                   'Bachelors', 'Masters', 'Doctorate', 'Prof-school']
data = data[data['education'].isin(keep_educations)]

# Reset index
data.reset_index(drop=True, inplace=True)
# Out:
# /tmp/ipython-input-51-720560512.py:4: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data['occupation'].replace('?', 'Others', inplace=True)
# /tmp/ipython-input-51-720560512.py:5: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# ...

# %%
# Drop 'education' since it may be redundant with education-num
data.drop(columns=['education'], inplace=True)

# Separate features and target
X = data.drop(columns=['income'])
y = data['income']

# Identify categorical columns (CatBoost can take them as-is!)
cat_cols = X.select_dtypes(include='object').columns.tolist()

# Train/test split
X_train, X_test, y_train, y_test = train_test_split(X, y,
                                                    test_size=0.2,
                                                    stratify=y,
                                                    random_state=42)

# %%
model = CatBoostClassifier(
    iterations=500,
    learning_rate=0.1,
    depth=6,
    eval_metric='Accuracy',
    cat_features=cat_cols,
    verbose=100,
    random_seed=42
)

model.fit(X_train, y_train)
# Out:
# 0:	learn: 0.8304552	total: 195ms	remaining: 1m 37s
# 100:	learn: 0.8640140	total: 6.53s	remaining: 25.8s
# 200:	learn: 0.8719364	total: 12.4s	remaining: 18.5s
# 300:	learn: 0.8766245	total: 19.1s	remaining: 12.6s
# 400:	learn: 0.8803038	total: 25.1s	remaining: 6.19s
# 499:	learn: 0.8838941	total: 32s	remaining: 0us

# %%
y_pred = model.predict(X_test)

print("✅ Accuracy:", accuracy_score(y_test, y_pred))
print("\n📋 Classification Report:\n", classification_report(y_test, y_pred))
# Out:
# ✅ Accuracy: 0.8582957512461429
#
# 📋 Classification Report:
#                precision    recall  f1-score   support
#
#        <=50K       0.88      0.93      0.91      6173
#         >50K       0.78      0.66      0.71      2253
#
#     accuracy                           0.86      8426
#    macro avg       0.83      0.79      0.81      8426
# weighted avg       0.85      0.86      0.85      8426

# %%
import matplotlib.pyplot as plt

feature_importance = model.get_feature_importance(prettified=True)
feature_importance.sort_values(by='Importances', ascending=True).plot.barh(x='Feature Id', y='Importances', figsize=(10, 6))
plt.title("Feature Importance - CatBoost")
plt.show()
